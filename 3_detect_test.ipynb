# %%
import matplotlib.pyplot as plt

# %%
# detect test image
save = False
if save:
    # !python ../yolov5/detect.py --weights detect_car_num/weights/best.pt --img 416 --conf 0.5 --source test_img --save-txt --save-crop --view-img
else:
    # !python ../yolov5/detect.py --weights detect_car_num/weights/best.pt --img 416 --conf 0.5 --source test_img --view-img
# Out:
# detect: weights=['detect_car_num/weights/best.pt'], source=test_img, data=..\yolov5\data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=True, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=..\yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-263-g0537e8d Python-3.9.4 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/3 D:\My_Git_Repositories\Driving_Control_System\test_img\01거0598.jpg: 224x416 1 car_number, Done. (0.095s)
# image 2/3 D:\My_Git_Repositories\Driving_Control_System\test_img\01누9353.jpg: 192x416 1 car_number, Done. (0.078s)
# image 3/3 D:\My_Git_Repositories\Driving_Control_System\test_img\01다1168.jpg: 256x416 1 car_number, Done. (0.096s)
# ...

# %%
import matplotlib.pyplot as plt

test_img = plt.imread('../yolov5/runs/detect/exp8/01거0598.jpg')
plt.imshow(test_img)
plt.show()

# %%
from PIL import Image
im = Image.open('../yolov5/runs/detect/exp8/01거0598.jpg')

print(im.size)
print(type(im.size))

print(0.7628205418586731*156)
print(0.792682945728302*82)
# Out:
# (156, 82)
# <class 'tuple'>
# 119.000004529953
# 65.00000154972076

# %%
cropim = Image.open('../yolov5/runs/detect/exp8/crops/car_number/01거0598.jpg')
print(cropim.shape)
print(type(cropim))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\My_Git_Repositories\Driving_Control_System\3_detect_test.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/My_Git_Repositories/Driving_Control_System/3_detect_test.ipynb#ch0000002?line=0'>1</a> cropim = Image.open('../yolov5/runs/detect/exp8/crops/car_number/01거0598.jpg')
# ----> <a href='vscode-notebook-cell:/d%3A/My_Git_Repositories/Driving_Control_System/3_detect_test.ipynb#ch0000002?line=1'>2</a> print(cropim.shape)
#       <a href='vscode-notebook-cell:/d%3A/My_Git_Repositories/Driving_Control_System/3_detect_test.ipynb#ch0000002?line=2'>3</a> print(type(cropim))
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py:548, in Image.__getattr__(self, name)
#     541     warnings.warn(
# ...
